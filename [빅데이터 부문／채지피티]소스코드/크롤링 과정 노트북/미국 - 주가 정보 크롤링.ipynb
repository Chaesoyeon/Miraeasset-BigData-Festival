# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
# from pykrx import stock
import io
import boto3

# %% [markdown]
# ### 미국 주식 주가 데이터 크롤링

# %%
# 미국 주식 종목&티커 불러오기
usa = pd.read_csv('해외_산업분류.csv')
usa
# Out:
#       Ticker                              Company                Industrials  \
# 0         AA                    Alcoa Corporation                   Aluminum
# 1       ACNT                Ascent Industries Co.                      Steel
# 2        ALB                Albemarle Corporation        Specialty Chemicals
# 3       ALTO               Alto Ingredients, Inc.        Specialty Chemicals
# 4        AMR  Alpha Metallurgical Resources, Inc.                Coking Coal
# ...      ...                                  ...                        ...
# 4878    OBDC         Owl Rock Capital Corporation            Credit Services
# 4879   HEI.A                    HEICO Corporation        Aerospace & Defense
# 4880   MOG.A                            Moog Inc.        Aerospace & Defense
# 4881  UHAL.B               U-Haul Holding Company  Rental & Leasing Services
# 4882  CWEN.A                Clearway Energy, Inc.      Utilities - Renewable
#
#       Market
# 0       NYSE
# 1     NASDAQ
# 2       NYSE
# 3     NASDAQ
# 4       NYSE
# ...      ...
# 4878    NYSE
# 4879    NYSE
# 4880    NYSE
# 4881    NYSE
# 4882    NYSE
#
# [4883 rows x 4 columns]

# %%
# yfinance에서 티커를 기준으로 데이터를 불러오려면 형태 변경이 필요
yf_usa = usa.copy()
yf_usa['Ticker'] = yf_usa['Ticker'].str.replace('.A', '-A', regex = False).str.replace('.B', '-B', regex = False)

# %%
yf_usa
# Out:
#       Ticker                              Company                Industrials  \
# 0         AA                    Alcoa Corporation                   Aluminum
# 1       ACNT                Ascent Industries Co.                      Steel
# 2        ALB                Albemarle Corporation        Specialty Chemicals
# 3       ALTO               Alto Ingredients, Inc.        Specialty Chemicals
# 4        AMR  Alpha Metallurgical Resources, Inc.                Coking Coal
# ...      ...                                  ...                        ...
# 4878    OBDC         Owl Rock Capital Corporation            Credit Services
# 4879   HEI-A                    HEICO Corporation        Aerospace & Defense
# 4880   MOG-A                            Moog Inc.        Aerospace & Defense
# 4881  UHAL-B               U-Haul Holding Company  Rental & Leasing Services
# 4882  CWEN-A                Clearway Energy, Inc.      Utilities - Renewable
#
#       Market
# 0       NYSE
# 1     NASDAQ
# 2       NYSE
# 3     NASDAQ
# 4       NYSE
# ...      ...
# 4878    NYSE
# 4879    NYSE
# 4880    NYSE
# 4881    NYSE
# 4882    NYSE
#
# [4883 rows x 4 columns]

# %%
usa
# Out:
#       Ticker                              Company                Industrials  \
# 0         AA                    Alcoa Corporation                   Aluminum
# 1       ACNT                Ascent Industries Co.                      Steel
# 2        ALB                Albemarle Corporation        Specialty Chemicals
# 3       ALTO               Alto Ingredients, Inc.        Specialty Chemicals
# 4        AMR  Alpha Metallurgical Resources, Inc.                Coking Coal
# ...      ...                                  ...                        ...
# 4878    OBDC         Owl Rock Capital Corporation            Credit Services
# 4879   HEI.A                    HEICO Corporation        Aerospace & Defense
# 4880   MOG.A                            Moog Inc.        Aerospace & Defense
# 4881  UHAL.B               U-Haul Holding Company  Rental & Leasing Services
# 4882  CWEN.A                Clearway Energy, Inc.      Utilities - Renewable
#
#       Market
# 0       NYSE
# 1     NASDAQ
# 2       NYSE
# 3     NASDAQ
# 4       NYSE
# ...      ...
# 4878    NYSE
# 4879    NYSE
# 4880    NYSE
# 4881    NYSE
# 4882    NYSE
#
# [4883 rows x 4 columns]

# %%
def collect_and_upload_stock_data(tickers, start_date, end_date, s3_client, bucket_name, endpoint_url, access_key, secret_key):
    failed_ls = []
    
    for ticker in tickers:
        data = yf.download(ticker, start=start_date, end=end_date)
        data['Change'] = data['Adj Close'].pct_change() * 100  # 등락률 계산
        data = data.drop('Adj Close', axis = 1)
        data['Ticker'] = ticker
        data = data[1:]  # 첫 번째 행 제거
        
        if data['Open'].eq(0).all():
            print(f"Data for {ticker} has all 'Open' values as 0. Skipping upload.")
            failed_ls.append(ticker)
            continue
            
        index = yf_usa[yf_usa['Ticker'] == ticker].index.values[0]
        title_ticker = usa.at[index, 'Ticker']

        # 데이터프레임을 파일로 저장
        xlsx_filename = f'{title_ticker}_주가데이터.xlsx'
        xlsx_buffer = io.BytesIO()
        data.to_excel(xlsx_buffer)
        xlsx_buffer.seek(0)

        # xlsx 파일 클라우드 업로드
        object_name = f'usa_stock_crawling/{xlsx_filename}'
        s3_client.upload_fileobj(xlsx_buffer, bucket_name, object_name)
        print(f"Uploaded {xlsx_filename} to S3")
        
    print('Failed tickers: ', failed_ls)

def main():
    # AWS S3 설정
    service_name = 's3'
    endpoint_url = 'https://kr.object.ncloudstorage.com'
    region_name = 'kr-standard'
    access_key = 'cPKhn3d9z9ZWYMAPPwyq'
    secret_key = 'VFjEkpateO6VFGY0U9op073I4NXTlejMBMIq6FvA'
    bucket_name = 'bucket1chaegpt'

    # 티커 리스트 생성
    
    usa_tickers = yf_usa.iloc[:,0].unique()

    # 오늘 날짜로부터 2년 전의 날짜 계산
    end_date = datetime.today()
    ## end에 설정한 일자의 전일자까지 조회됨.
    start_date = (datetime.today() - timedelta(days=365*2 + 1))
    ## 2년전+1일전 데이터를 수집해야 2년 전날까지의 등락률을 계산할 수 있음.

    # AWS S3 클라이언트 생성
    s3 = boto3.client(service_name, endpoint_url=endpoint_url, aws_access_key_id=access_key,
                      aws_secret_access_key=secret_key)

    # 클라우드 폴더 생성
    object_name = 'usa_stock_crawling/'
    s3.put_object(Bucket=bucket_name, Key=object_name)

    # 주가 데이터 수집 및 파일로 저장
    collect_and_upload_stock_data(usa_tickers, start_date, end_date, s3, bucket_name, endpoint_url,
                                  access_key, secret_key)

if __name__ == '__main__':
    main()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ACNT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ALB_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ALTO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AMR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded APD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ARCH_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AREC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ASH_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ASIX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ASPI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AUMN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AVD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AVNT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AVTR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AXTA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BCC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BCPC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BHIL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CBT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CCF_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CDE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CENX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CF_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CLF_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CLW_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CMC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CMP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CMT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CRKN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CTGO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CTVA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded DC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded DD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded DNMR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded DOW_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ECL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ECVT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded EMN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ESI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded EVA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded EXP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded FCX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded FEAM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded FF_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded FMC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded FRD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded FUL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded GEVO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded GLT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded GORO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded GPRE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HCC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HDSN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HUN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HWKN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HYMC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded IAUX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded IDR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded IFF_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded IOSP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded IPI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded IPX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded JCTCF_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded KALU_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded KNF_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded KOP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded KRO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded KWR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded LTHM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded LWLG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded LXU_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded LYB_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MATV_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded METC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded METCB_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MLM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MOS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MSB_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MTRN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MTX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NB_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NEM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NEU_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NGVT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NTIC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NUE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ODC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded OLN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ORGN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PLL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PLM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PPG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PPTA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PRM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PZG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded REX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded RGLD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded RPM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded RS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded RYAM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SCCO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SCHN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SCL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SHW_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SLVM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SMG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SMID_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SNES_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SSD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SSRM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded STLD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SUM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SXC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SXT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded TMST_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded TROX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded TSE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded UAMY_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded UAN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded UFPI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded USAP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded USAU_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded USGO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded USLM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded VGZ_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded VHI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded VMC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded WDFC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded WLK_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded WLKP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded WTTR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded WWR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded X_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded XPL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded YTEN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ZEUS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ADD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ADTH_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ADV_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AENT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AGAE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AMC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AMCX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ANGI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded AREN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ASST_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ATEX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ATNI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ATUS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ATVI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BATRA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BATRK_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BBGI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BOC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BODY_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BZFD_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CABO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CCO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CCOI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CDLX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CHTR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CMCSA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CMLS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CNK_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CNSL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CNVS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded COMS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CRGE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CSSE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CSSEP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CTV_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded
_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CEG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CMS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CNP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CPK_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CWEN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CWT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded D_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded DTE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded DUK_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ED_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded EE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded EIX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ES_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ETR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded EVRG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded EXC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded FE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded FLNC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded GNE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded GWRS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HLGN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded IDA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded LNT_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MGEE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MNTK_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MSEX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NEE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NEP_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NFE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NIMC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NJR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NRG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NRGV_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NWE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded NWN_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded OGE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded OGS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded OPAL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ORA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded OTTR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PCG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PCYO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PEG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PNM_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PNW_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded POR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded PPL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded RGCO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SJW_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SPH_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SR_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SRE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded SWX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded TVE_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded UGI_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded UTL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded VGAS_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded VIA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded VST_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded WEC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded WTRG_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded XEL_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded YORW_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded LGF.A_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded LGF.B_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded GEF.B_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded LEN.B_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded Bf.A_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BF.B_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BGC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BRK.A_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BRK.B_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CRD.A_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CRD.B_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded ESHA_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded OBDC_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HEI.A_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded MOG.A_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded UHAL.B_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded CWEN.A_주가데이터.xlsx to S3
# Failed tickers:  ['GOGO', 'HLX', 'BCML', 'BREZR']

# %%
# failed_ls 다시 돌리기
failed_ls = ['GOGO', 'HLX', 'BCML', 'BREZR']

def main():
    # AWS S3 설정
    service_name = 's3'
    endpoint_url = 'https://kr.object.ncloudstorage.com'
    region_name = 'kr-standard'
    access_key = 'cPKhn3d9z9ZWYMAPPwyq'
    secret_key = 'VFjEkpateO6VFGY0U9op073I4NXTlejMBMIq6FvA'
    bucket_name = 'bucket1chaegpt'

    # 티커 리스트 생성
    retry_tic = failed_ls 

    # 오늘 날짜로부터 2년 전의 날짜 계산
    end_date = datetime.today()
    ## end에 설정한 일자의 전일자까지 조회됨.
    start_date = (datetime.today() - timedelta(days=365*2 + 1))
    ## 2년전+1일전 데이터를 수집해야 2년 전날까지의 등락률을 계산할 수 있음.

    # AWS S3 클라이언트 생성
    s3 = boto3.client(service_name, endpoint_url=endpoint_url, aws_access_key_id=access_key,
                      aws_secret_access_key=secret_key)

    # 클라우드 폴더 생성
    object_name = 'usa_stock_crawling/'
    s3.put_object(Bucket=bucket_name, Key=object_name)

    # 주가 데이터 수집 및 파일로 저장
    collect_and_upload_stock_data(retry_tic, start_date, end_date, s3, bucket_name, endpoint_url,
                                  access_key, secret_key)

if __name__ == '__main__':
    main()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Uploaded GOGO_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded HLX_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Uploaded BCML_주가데이터.xlsx to S3
# [*********************100%%**********************]  1 of 1 completed
# Data for BREZR has all 'Open' values as 0. Skipping upload.
# Failed tickers:  ['BREZR']

# %%
# BREZR 행 삭제 - 2년 기간 중 하루치 데이터밖에 없어서
usa = usa[usa['Ticker'] != 'BREZR']
usa
# Out:
#       Ticker                              Company                Industrials  \
# 0         AA                    Alcoa Corporation                   Aluminum
# 1       ACNT                Ascent Industries Co.                      Steel
# 2        ALB                Albemarle Corporation        Specialty Chemicals
# 3       ALTO               Alto Ingredients, Inc.        Specialty Chemicals
# 4        AMR  Alpha Metallurgical Resources, Inc.                Coking Coal
# ...      ...                                  ...                        ...
# 4878    OBDC         Owl Rock Capital Corporation            Credit Services
# 4879   HEI.A                    HEICO Corporation        Aerospace & Defense
# 4880   MOG.A                            Moog Inc.        Aerospace & Defense
# 4881  UHAL.B               U-Haul Holding Company  Rental & Leasing Services
# 4882  CWEN.A                Clearway Energy, Inc.      Utilities - Renewable
#
#       Market
# 0       NYSE
# 1     NASDAQ
# 2       NYSE
# 3     NASDAQ
# 4       NYSE
# ...      ...
# 4878    NYSE
# 4879    NYSE
# 4880    NYSE
# 4881    NYSE
# 4882    NYSE
#
# [4882 rows x 4 columns]

# %%
usa.to_csv('해외_산업분류(추가제거).csv')
